# %%
import numpy as np

# %%
pixelx= np.arange(500)*15.+7.5

# %%
pixelx
# Out:
# array([   7.5,   22.5,   37.5,   52.5,   67.5,   82.5,   97.5,  112.5,
#         127.5,  142.5,  157.5,  172.5,  187.5,  202.5,  217.5,  232.5,
#         247.5,  262.5,  277.5,  292.5,  307.5,  322.5,  337.5,  352.5,
#         367.5,  382.5,  397.5,  412.5,  427.5,  442.5,  457.5,  472.5,
#         487.5,  502.5,  517.5,  532.5,  547.5,  562.5,  577.5,  592.5,
#         607.5,  622.5,  637.5,  652.5,  667.5,  682.5,  697.5,  712.5,
#         727.5,  742.5,  757.5,  772.5,  787.5,  802.5,  817.5,  832.5,
#         847.5,  862.5,  877.5,  892.5,  907.5,  922.5,  937.5,  952.5,
#         967.5,  982.5,  997.5, 1012.5, 1027.5, 1042.5, 1057.5, 1072.5,
#        1087.5, 1102.5, 1117.5, 1132.5, 1147.5, 1162.5, 1177.5, 1192.5,
#        1207.5, 1222.5, 1237.5, 1252.5, 1267.5, 1282.5, 1297.5, 1312.5,
#        1327.5, 1342.5, 1357.5, 1372.5, 1387.5, 1402.5, 1417.5, 1432.5,
#        1447.5, 1462.5, 1477.5, 1492.5, 1507.5, 1522.5, 1537.5, 1552.5,
# ...

# %%
spherex=4000.

# %%
ii = (np.where(np.abs(pixelx-spherex)== np.min(np.abs(pixelx-spherex))))[0]

# %%
ii
# Out:
# 266

# %%
pixelx[ii]
# Out:
# 3997.5

# %%
# Out:
# 266
